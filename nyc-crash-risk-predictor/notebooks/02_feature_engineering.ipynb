# %% [markdown]
# # 02 Feature Engineering
#
# Build the hourly crash-rate table used by the Monte Carlo simulation.

# %%
from pathlib import Path
import sys
import pandas as pd

PROJECT_ROOT = Path.cwd().parent if Path.cwd().name == "notebooks" else Path.cwd()
if str(PROJECT_ROOT) not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT))

from src.feature_engineering import build_crash_rate_table

# %%
cleaned_path = PROJECT_ROOT / "data" / "processed" / "nyc_crashes_clean.csv"
rate_path = PROJECT_ROOT / "data" / "processed" / "crash_rate_table.csv"

if not cleaned_path.exists():
    raise FileNotFoundError("Run notebook 01 or python main.py first.")

rate_table = build_crash_rate_table(cleaned_path=cleaned_path, output_path=rate_path)
rate_table.head()

# %% [markdown]
# `observed_hours` is the exposure term. If the dataset covers 20 Fridays, each Friday/hour ZIP bucket has 20 observed one-hour periods.

# %%
rate_table.sort_values("estimated_lambda", ascending=False).head(10)

# %%
rate_table["estimated_lambda"].describe()
